# %%
import sys
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import investpy

# %%
def SMAIndicator(data, length):
    sma = data.rolling(window=length).mean()
    return sma

def realtime_scan(country_name, direction, time_frame):
    all_stocks = investpy.get_stocks_list(country=country_name)
    
    stock_type = 'equity'
    fromdate = '01/01/2017'
    todate = '01/01/2023'
    log = ''
    
    print('Realtime... Scanning {} stocks'.format(len(all_stocks)))
    print('Please wait...')
    
    for eachstock in all_stocks:
        try:
            stock_name = eachstock
            df = investpy.get_stock_historical_data(stock=stock_name, country=country_name, from_date=fromdate, to_date=todate)

            if time_frame == '1D':
                data = df['Close'].copy()
                sma18 = SMAIndicator(data, 18)
                
            else:
                data = df['Close'].copy()
                m_close = data.resample(time_frame, base=0).last()
                sma18 = SMAIndicator(m_close, 18)
            

            if direction == 'Long':
                for i in range(len(sma18)-1, len(sma18)):
                    if sma18[i]>sma18[i-1] and sma18[i-1]<sma18[i-2]:
                        print('Ticker:', stock_name, '  Date:', sma18.index[i], '  SMA-Price:', round(sma18[i],2))
                        if log == '':
                            log = '{}'.format(eachstock)
                        else:
                            log = log + ',{}'.format(eachstock)              
                        
            elif direction == 'Short':
                for i in range(len(sma18)-1, len(sma18)):
                    if sma18[i]<sma18[i-1] and sma18[i-1]>sma18[i-2]:
                        print('Ticker:', stock_name, '  Date:', sma18.index[i], '  SMA-Price:', round(sma18[i],2))
                        if log == '':
                            log = '{}'.format(eachstock)
                        else:
                            log = log + ',{}'.format(eachstock)
                              
        except:
            pass
    
    return log

stocks_countries = investpy.get_stock_countries()
print('Countries List')
print(str(stocks_countries))
# Out:
# Countries List
# ...

# %% [markdown]
# ## STOCK SCREENER
# ### Scan all stocks in realtime for change and print result

# %%
print('China')
log = realtime_scan('china', 'Long', '1M')

print('Finished... done')

file1 = open("Long_DataFile_china_M.txt", "w+") 
file1.write(log)
file1.close() 
print('Saving file... done')
print('\n')


print('Hong Kong')
log = realtime_scan('Hong Kong', 'Long', '1M')

print('Finished... done')

file1 = open("Long_DataFile_hong_kong_M.txt", "w+") 
file1.write(log)
file1.close() 
print('Saving file... done')
print('\n')


print('United States')
log = realtime_scan('united states', 'Long', '1M')

print('Finished... done')

file1 = open("Long_DataFile_united_states_M.txt", "w+") 
file1.write(log)
file1.close() 
print('Saving file... done')
print('\n')


print('Russia')
log = realtime_scan('Russia', 'Long', '1M')

print('Finished... done')

file1 = open("Long_DataFile_russia_M.txt", "w+") 
file1.write(log)
file1.close() 
print('Saving file... done')
print('\n')


print('Japan')
log = realtime_scan('Japan', 'Long', '1M')

print('Finished... done')

file1 = open("Long_DataFile_japan_M.txt", "w+") 
file1.write(log)
file1.close() 
print('Saving file... done')
print('\n')


print('Canada')
log = realtime_scan('canada', 'Long', '1M')

print('Finished... done')

file1 = open("Long_DataFile_canada_M.txt", "w+") 
file1.write(log)
file1.close() 
print('Saving file... done')
print('\n')


print('Mexico')
log = realtime_scan('mexico', 'Long', '1M')

print('Finished... done')

file1 = open("Long_DataFile_mexico_M.txt", "w+") 
file1.write(log)
file1.close() 
print('Saving file... done')
print('\n')


print('Austria')
log = realtime_scan('austria', 'Long', '1M')

print('Finished... done')

file1 = open("Long_DataFile_austria_M.txt", "w+") 
file1.write(log)
file1.close() 
print('Saving file... done')
print('\n')


print('Belgium')
log = realtime_scan('belgium', 'Long', '1M')

print('Finished... done')

file1 = open("Long_DataFile_belgium_M.txt", "w+") 
file1.write(log)
file1.close() 
print('Saving file... done')
print('\n')


print('France')
log = realtime_scan('france', 'Long', '1M')

print('Finished... done')

file1 = open("Long_DataFile_france_M.txt", "w+") 
file1.write(log)
file1.close() 
print('Saving file... done')
print('\n')


print('Germany')
log = realtime_scan('germany', 'Long', '1M')

print('Finished... done')

file1 = open("Long_DataFile_germany_M.txt", "w+") 
file1.write(log)
file1.close() 
print('Saving file... done')
print('\n')


print('Hungary')
log = realtime_scan('hungary', 'Long', '1M')

print('Finished... done')

file1 = open("Long_DataFile_hungary_M.txt", "w+") 
file1.write(log)
file1.close() 
print('Saving file... done')
print('\n')


print('Israel')
log = realtime_scan('israel', 'Long', '1M')

print('Finished... done')

file1 = open("Long_DataFile_israel_M.txt", "w+") 
file1.write(log)
file1.close() 
print('Saving file... done')
print('\n')


print('Italy')
log = realtime_scan('Italy', 'Long', '1M')

print('Finished... done')

file1 = open("Long_DataFile_italy_M.txt", "w+") 
file1.write(log)
file1.close() 
print('Saving file... done')
print('\n')


print('Netherlands')
log = realtime_scan('Netherlands', 'Long', '1M')

print('Finished... done')

file1 = open("Long_DataFile_netherlands_M.txt", "w+") 
file1.write(log)
file1.close() 
print('Saving file... done')
print('\n')


print('Norway')
log = realtime_scan('Norway', 'Long', '1M')

print('Finished... done')

file1 = open("Long_DataFile_norway_M.txt", "w+") 
file1.write(log)
file1.close() 
print('Saving file... done')
print('\n')


print('Poland')
log = realtime_scan('poland', 'Long', '1M')

print('Finished... done')

file1 = open("Long_DataFile_poland_M.txt", "w+") 
file1.write(log)
file1.close() 
print('Saving file... done')
print('\n')


print('Portugal')
log = realtime_scan('Portugal', 'Long', '1M')

print('Finished... done')

file1 = open("Long_DataFile_portugal_M.txt", "w+") 
file1.write(log)
file1.close() 
print('Saving file... done')
print('\n')


print('Spain')
log = realtime_scan('Spain', 'Long', '1M')

print('Finished... done')

file1 = open("Long_DataFile_spain_M.txt", "w+") 
file1.write(log)
file1.close() 
print('Saving file... done')
print('\n')


print('Sweden')
log = realtime_scan('Sweden', 'Long', '1M')

print('Finished... done')

file1 = open("Long_DataFile_sweden_M.txt", "w+") 
file1.write(log)
file1.close() 
print('Saving file... done')
print('\n')


print('Switzerland')
log = realtime_scan('Switzerland', 'Long', '1M')

print('Finished... done')

file1 = open("Long_DataFile_switzerland_M.txt", "w+") 
file1.write(log)
file1.close() 
print('Saving file... done')
print('\n')


print('United Kingdom')
log = realtime_scan('United Kingdom', 'Long', '1M')

print('Finished... done')

file1 = open("Long_DataFile_united_kingdom_M.txt", "w+") 
file1.write(log)
file1.close() 
print('Saving file... done')
print('\n')


print('Australia')
log = realtime_scan('Australia', 'Long', '1M')

print('Finished... done')

file1 = open("Long_DataFile_australia_M.txt", "w+") 
file1.write(log)
file1.close() 
print('Saving file... done')
print('\n')


print('India')
log = realtime_scan('India', 'Long', '1M')

print('Finished... done')

file1 = open("Long_DataFile_india_M.txt", "w+") 
file1.write(log)
file1.close() 
print('Saving file... done')
print('\n')


print('Singapore')
log = realtime_scan('Singapore', 'Long', '1M')

print('Finished... done')

file1 = open("Long_DataFile_singapore_M.txt", "w+") 
file1.write(log)
file1.close() 
print('Saving file... done')
print('\n')


print('South Korea')
log = realtime_scan('South Korea', 'Long', '1M')

print('Finished... done')

file1 = open("Long_DataFile_south_korea_M.txt", "w+") 
file1.write(log)
file1.close() 
print('Saving file... done')


#**********************************************************


print('China')
log = realtime_scan('china', 'Short', '1M')

print('Finished... done')

file1 = open("Short_DataFile_china_M.txt", "w+") 
file1.write(log)
file1.close() 
print('Saving file... done')
print('\n')


print('Hong Kong')
log = realtime_scan('Hong Kong', 'Short', '1M')

print('Finished... done')

file1 = open("Short_DataFile_hong_kong_M.txt", "w+") 
file1.write(log)
file1.close() 
print('Saving file... done')
print('\n')


print('United States')
log = realtime_scan('united states', 'Short', '1M')

print('Finished... done')

file1 = open("Short_DataFile_united_states_M.txt", "w+") 
file1.write(log)
file1.close() 
print('Saving file... done')
print('\n')


print('Russia')
log = realtime_scan('Russia', 'Short', '1M')

print('Finished... done')

file1 = open("Short_DataFile_russia_M.txt", "w+") 
file1.write(log)
file1.close() 
print('Saving file... done')
print('\n')


print('Japan')
log = realtime_scan('Japan', 'Short', '1M')

print('Finished... done')

file1 = open("Short_DataFile_japan_M.txt", "w+") 
file1.write(log)
file1.close() 
print('Saving file... done')
print('\n')


print('Canada')
log = realtime_scan('canada', 'Short', '1M')

print('Finished... done')

file1 = open("Short_DataFile_canada_M.txt", "w+") 
file1.write(log)
file1.close() 
print('Saving file... done')
print('\n')


print('Mexico')
log = realtime_scan('mexico', 'Short', '1M')

print('Finished... done')

file1 = open("Short_DataFile_mexico_M.txt", "w+") 
file1.write(log)
file1.close() 
print('Saving file... done')
print('\n')


print('Austria')
log = realtime_scan('austria', 'Short', '1M')

print('Finished... done')

file1 = open("Short_DataFile_austria_M.txt", "w+") 
file1.write(log)
file1.close() 
print('Saving file... done')
print('\n')


print('Belgium')
log = realtime_scan('belgium', 'Short', '1M')

print('Finished... done')

file1 = open("Short_DataFile_belgium_M.txt", "w+") 
file1.write(log)
file1.close() 
print('Saving file... done')
print('\n')


print('France')
log = realtime_scan('france', 'Short', '1M')

print('Finished... done')

file1 = open("Short_DataFile_france_M.txt", "w+") 
file1.write(log)
file1.close() 
print('Saving file... done')
print('\n')


print('Germany')
log = realtime_scan('germany', 'Short', '1M')

print('Finished... done')

file1 = open("Short_DataFile_germany_M.txt", "w+") 
file1.write(log)
file1.close() 
print('Saving file... done')
print('\n')


print('Hungary')
log = realtime_scan('hungary', 'Short', '1M')

print('Finished... done')

file1 = open("Short_DataFile_hungary_M.txt", "w+") 
file1.write(log)
file1.close() 
print('Saving file... done')
print('\n')


print('Israel')
log = realtime_scan('israel', 'Short', '1M')

print('Finished... done')

file1 = open("Short_DataFile_israel_M.txt", "w+") 
file1.write(log)
file1.close() 
print('Saving file... done')
print('\n')


print('Italy')
log = realtime_scan('Italy', 'Short', '1M')

print('Finished... done')

file1 = open("Short_DataFile_italy_M.txt", "w+") 
file1.write(log)
file1.close() 
print('Saving file... done')
print('\n')


print('Netherlands')
log = realtime_scan('Netherlands', 'Short', '1M')

print('Finished... done')

file1 = open("Short_DataFile_netherlands_M.txt", "w+") 
file1.write(log)
file1.close() 
print('Saving file... done')
print('\n')


print('Norway')
log = realtime_scan('Norway', 'Short', '1M')

print('Finished... done')

file1 = open("Short_DataFile_norway_M.txt", "w+") 
file1.write(log)
file1.close() 
print('Saving file... done')
print('\n')


print('Poland')
log = realtime_scan('poland', 'Short', '1M')

print('Finished... done')

file1 = open("Short_DataFile_poland_M.txt", "w+") 
file1.write(log)
file1.close() 
print('Saving file... done')
print('\n')


print('Portugal')
log = realtime_scan('Portugal', 'Short', '1M')

print('Finished... done')

file1 = open("Short_DataFile_portugal_M.txt", "w+") 
file1.write(log)
file1.close() 
print('Saving file... done')
print('\n')


print('Spain')
log = realtime_scan('Spain', 'Short', '1M')

print('Finished... done')

file1 = open("Short_DataFile_spain_M.txt", "w+") 
file1.write(log)
file1.close() 
print('Saving file... done')
print('\n')


print('Sweden')
log = realtime_scan('Sweden', 'Short', '1M')

print('Finished... done')

file1 = open("Short_DataFile_sweden_M.txt", "w+") 
file1.write(log)
file1.close() 
print('Saving file... done')
print('\n')


print('Switzerland')
log = realtime_scan('Switzerland', 'Short', '1M')

print('Finished... done')

file1 = open("Short_DataFile_switzerland_M.txt", "w+") 
file1.write(log)
file1.close() 
print('Saving file... done')
print('\n')


print('United Kingdom')
log = realtime_scan('United Kingdom', 'Short', '1M')

print('Finished... done')

file1 = open("Short_DataFile_united_kingdom_M.txt", "w+") 
file1.write(log)
file1.close() 
print('Saving file... done')
print('\n')


print('Australia')
log = realtime_scan('Australia', 'Short', '1M')

print('Finished... done')

file1 = open("Short_DataFile_australia_M.txt", "w+") 
file1.write(log)
file1.close() 
print('Saving file... done')
print('\n')


print('India')
log = realtime_scan('India', 'Short', '1M')

print('Finished... done')

file1 = open("Short_DataFile_india_M.txt", "w+") 
file1.write(log)
file1.close() 
print('Saving file... done')
print('\n')


print('Singapore')
log = realtime_scan('Singapore', 'Short', '1M')

print('Finished... done')

file1 = open("Short_DataFile_singapore_M.txt", "w+") 
file1.write(log)
file1.close() 
print('Saving file... done')
print('\n')


print('South Korea')
log = realtime_scan('Long_South Korea', 'Short', '1M')

print('Finished... done')

file1 = open("Short_DataFile_south_korea_M.txt", "w+") 
file1.write(log)
file1.close() 
print('Saving file... done')
# Out:
# China
# Realtime... Scanning 3339 stocks
# Please wait...
# <ipython-input-2-e1bedf769b75>:27: FutureWarning: 'base' in .resample() and in Grouper() is deprecated.
# The new arguments that you should use are 'offset' or 'origin'.
#
# >>> df.resample(freq="3s", base=2)
#
# becomes:
#
# >>> df.resample(freq="3s", offset="2s")
#
#   m_close = data.resample(time_frame, base=0).last()
# Ticker: 600012   Date: 2021-01-31 00:00:00   SMA-Price: 5.52
# Ticker: 600019   Date: 2021-01-31 00:00:00   SMA-Price: 5.41
# Ticker: 600061   Date: 2021-01-31 00:00:00   SMA-Price: 13.47
# Ticker: 600064   Date: 2021-01-31 00:00:00   SMA-Price: 9.71
# Ticker: 600052   Date: 2021-01-31 00:00:00   SMA-Price: 3.85
# Ticker: 600084   Date: 2021-01-31 00:00:00   SMA-Price: 2.4
# Ticker: 600097   Date: 2021-01-31 00:00:00   SMA-Price: 9.91
# Ticker: 600104   Date: 2021-01-31 00:00:00   SMA-Price: 21.9
# Ticker: 600155   Date: 2021-01-31 00:00:00   SMA-Price: 12.51
# ...
